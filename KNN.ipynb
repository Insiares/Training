# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.neighbors import KNeighborsClassifier

# %%
digits= load_digits()
X= digits.data
y= digits.target
print('dimension de x :', X.shape)
print('dimension de y:', y.shape)
# Out:
# dimension de x : (1797, 64)
# dimension de y: (1797,)

# %%
plt.imshow(digits['images'][0], cmap='Greys_r')

# %%
model = KNeighborsClassifier()
model.fit(X,y)
print('score:', model.score(X,y))
# Out:
# score: 0.9905397885364496

# %%
i= 8
test= digits['images'][i]
testr= test.reshape(1,-1)
print('Test brut', test)
print('reshaped : ',testr)
# Out:
# Test brut [[ 0.  0. 11. 12.  0.  0.  0.  0.]
#  [ 0.  2. 16. 16. 16. 13.  0.  0.]
#  [ 0.  3. 16. 12. 10. 14.  0.  0.]
#  [ 0.  1. 16.  1. 12. 15.  0.  0.]
#  [ 0.  0. 13. 16.  9. 15.  2.  0.]
#  [ 0.  0.  0.  3.  0.  9. 11.  0.]
#  [ 0.  0.  0.  0.  9. 15.  4.  0.]
#  [ 0.  0.  9. 12. 13.  3.  0.  0.]]
# reshaped :  [[ 0.  0. 11. 12.  0.  0.  0.  0.  0.  2. 16. 16. 16. 13.  0.  0.  0.  3.
#   16. 12. 10. 14.  0.  0.  0.  1. 16.  1. 12. 15.  0.  0.  0.  0. 13. 16.
#    9. 15.  2.  0.  0.  0.  0.  3.  0.  9. 11.  0.  0.  0.  0.  0.  9. 15.
#    4.  0.  0.  0.  9. 12. 13.  3.  0.  0.]]

# %%
plt.imshow(digits['images'][i], cmap='Greys_r')
model.predict(testr)
# Out:
# array([9])
